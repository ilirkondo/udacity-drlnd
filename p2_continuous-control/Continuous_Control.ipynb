# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
import time
from collections import deque

import matplotlib.pyplot as plt
import numpy as np
import torch
from unityagents import UnityEnvironment

from agent import DDPGAgent 
from plotter import Plotter

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='./Reacher_Linux_20_agents/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# there are 20 identical agents, each with its own copy of the environment.
num_agents = len(env_info.agents) 
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.17099999617785216

# %% [markdown]
# When finished, you can close the environment.

# %% [markdown]
# ### 4. Training the Agent

# %%
agent = DDPGAgent(state_size, action_size, random_seed=0)
scores, moving_avg = agent.train(env)
# Out:
# DDPG Agent hyper parameters:
# batch size:                   128
# buffer size:               100000
# reward discount - gamma:    0.990
# actor learning rate:        0.001
# critic learning rate:       0.001
# soft update - tau:          0.001
# noise decay rate:           0.999
# target episodes:              100
# target score:                  30
# moving average window:         20
#
# Actor network: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=400, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=4, bias=True)
# )
# Actor network: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=400, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=4, bias=True)
# )
# Critic network: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=404, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=1, bias=True)
# )
# Critic network: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=404, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=1, bias=True)
# )
# Episode   1 - 07:24 - Score: 1.04 (max: 1.87 - min: 0.44)
# Moving average: 1.04 (max: 1.87 - min: 0.44)
#
# Episode   2 - 07:30 - Score: 2.81 (max: 4.79 - min: 0.69)
# Moving average: 1.93 (max: 3.16 - min: 0.63)
#
# Episode   3 - 07:20 - Score: 3.97 (max: 7.92 - min: 2.00)
# Moving average: 2.61 (max: 3.55 - min: 1.54)
#
# Episode   4 - 07:52 - Score: 4.91 (max: 8.24 - min: 2.08)
# Moving average: 3.18 (max: 4.72 - min: 1.93)
#
# Episode   5 - 07:49 - Score: 6.35 (max: 9.43 - min: 3.84)
# Moving average: 3.82 (max: 5.12 - min: 2.63)
#
# Episode   6 - 07:49 - Score: 9.78 (max: 14.51 - min: 7.01)
# Moving average: 4.81 (max: 5.73 - min: 3.71)
#
# Episode   7 - 07:53 - Score: 11.28 (max: 17.57 - min: 5.29)
# Moving average: 5.73 (max: 6.79 - min: 4.09)
#
# Episode   8 - 07:50 - Score: 11.98 (max: 19.46 - min: 4.88)
# Moving average: 6.51 (max: 7.64 - min: 4.54)
#
# Episode   9 - 07:46 - Score: 12.81 (max: 21.45 - min: 6.55)
# Moving average: 7.21 (max: 8.73 - min: 5.09)
#
# Episode  10 - 07:48 - Score: 11.25 (max: 17.56 - min: 5.28)
# Moving average: 7.62 (max: 9.62 - min: 5.66)
#
# Saving model ...
#
# Episode  11 - 07:49 - Score: 15.92 (max: 21.92 - min: 9.16)
# Moving average: 8.37 (max: 10.22 - min: 6.21)
#
# Episode  12 - 07:55 - Score: 16.52 (max: 23.86 - min: 6.76)
# Moving average: 9.05 (max: 11.13 - min: 6.33)
#
# Episode  13 - 07:46 - Score: 16.62 (max: 24.94 - min: 6.47)
# Moving average: 9.63 (max: 12.05 - min: 6.66)
#
# Episode  14 - 07:48 - Score: 15.63 (max: 21.71 - min: 9.11)
# Moving average: 10.06 (max: 12.61 - min: 7.44)
#
# Episode  15 - 07:44 - Score: 16.34 (max: 22.11 - min: 10.53)
# Moving average: 10.48 (max: 12.58 - min: 8.07)
#
# Episode  16 - 07:42 - Score: 17.44 (max: 27.63 - min: 5.65)
# Moving average: 10.91 (max: 13.03 - min: 8.99)
#
# Episode  17 - 07:31 - Score: 20.38 (max: 30.20 - min: 9.46)
# Moving average: 11.47 (max: 13.86 - min: 10.12)
#
# Episode  18 - 07:42 - Score: 27.45 (max: 34.34 - min: 19.85)
# Moving average: 12.36 (max: 14.58 - min: 10.91)
#
# Episode  19 - 07:39 - Score: 28.79 (max: 36.31 - min: 18.84)
# Moving average: 13.22 (max: 15.61 - min: 11.70)
#
# Episode  20 - 07:37 - Score: 32.29 (max: 39.16 - min: 26.34)
# Moving average: 14.18 (max: 16.33 - min: 12.51)
#
# Saving model ...
#
# Episode  21 - 07:43 - Score: 23.75 (max: 32.00 - min: 14.77)
# Moving average: 15.31 (max: 17.45 - min: 13.62)
#
# Episode  22 - 07:40 - Score: 30.66 (max: 36.56 - min: 21.72)
# Moving average: 16.71 (max: 18.95 - min: 15.15)
#
# Episode  23 - 07:45 - Score: 32.42 (max: 38.78 - min: 16.97)
# Moving average: 18.13 (max: 20.76 - min: 16.31)
#
# Episode  24 - 07:50 - Score: 32.29 (max: 39.36 - min: 22.17)
# Moving average: 19.50 (max: 22.10 - min: 17.73)
#
# Episode  25 - 07:52 - Score: 29.82 (max: 36.94 - min: 14.86)
# Moving average: 20.67 (max: 23.33 - min: 18.71)
#
# Episode  26 - 07:47 - Score: 34.27 (max: 39.40 - min: 25.57)
# Moving average: 21.90 (max: 24.31 - min: 19.89)
#
# Episode  27 - 07:47 - Score: 32.12 (max: 38.00 - min: 25.47)
# Moving average: 22.94 (max: 25.40 - min: 20.86)
#
# Episode  28 - 07:53 - Score: 34.16 (max: 36.19 - min: 30.41)
# Moving average: 24.05 (max: 26.26 - min: 21.87)
#
# Episode  29 - 07:50 - Score: 33.22 (max: 38.80 - min: 22.31)
# Moving average: 25.07 (max: 26.84 - min: 23.17)
#
# Episode  30 - 07:56 - Score: 34.19 (max: 39.37 - min: 27.32)
# Moving average: 26.21 (max: 27.72 - min: 24.27)
#
# Saving model ...
#
# Episode  31 - 07:53 - Score: 32.36 (max: 39.32 - min: 18.93)
# Moving average: 27.04 (max: 28.76 - min: 25.07)
#
# Episode  32 - 07:56 - Score: 37.45 (max: 39.42 - min: 33.79)
# Moving average: 28.08 (max: 29.61 - min: 26.38)
#
# Episode  33 - 07:55 - Score: 35.46 (max: 38.62 - min: 31.16)
# Moving average: 29.03 (max: 30.30 - min: 27.53)
#
# Episode  34 - 07:58 - Score: 35.78 (max: 39.55 - min: 26.16)
# Moving average: 30.03 (max: 31.22 - min: 28.67)
#
# Episode  35 - 07:51 - Score: 35.31 (max: 38.02 - min: 31.56)
# Moving average: 30.98 (max: 32.33 - min: 29.52)
#
# Episode  36 - 07:55 - Score: 33.66 (max: 37.74 - min: 24.62)
# Moving average: 31.79 (max: 33.19 - min: 30.36)
#
# Episode  37 - 07:51 - Score: 35.61 (max: 38.55 - min: 25.72)
# Moving average: 32.55 (max: 33.75 - min: 31.36)
#
# Episode  38 - 07:55 - Score: 35.82 (max: 38.42 - min: 30.90)
# Moving average: 32.97 (max: 34.25 - min: 31.69)
#
# Episode  39 - 07:55 - Score: 32.50 (max: 39.24 - min: 14.22)
# Moving average: 33.16 (max: 34.49 - min: 32.08)
#
# Episode  40 - 07:53 - Score: 33.73 (max: 38.79 - min: 27.67)
# Moving average: 33.23 (max: 34.75 - min: 31.98)
#
# Saving model ...
#
# Episode  41 - 07:56 - Score: 33.65 (max: 38.48 - min: 25.05)
# Moving average: 33.72 (max: 35.63 - min: 32.68)
#
# Episode  42 - 08:03 - Score: 29.10 (max: 38.76 - min: 9.34)
# Moving average: 33.65 (max: 35.57 - min: 31.96)
#
# Episode  43 - 07:58 - Score: 31.98 (max: 38.75 - min: 23.28)
# Moving average: 33.62 (max: 35.10 - min: 31.75)
#
# Episode  44 - 08:00 - Score: 32.01 (max: 38.82 - min: 21.21)
# Moving average: 33.61 (max: 34.80 - min: 31.69)
#
# Episode  45 - 07:59 - Score: 36.93 (max: 38.98 - min: 30.68)
# Moving average: 33.97 (max: 35.41 - min: 32.23)
#
# Episode  46 - 08:00 - Score: 34.88 (max: 38.49 - min: 26.86)
# Moving average: 34.00 (max: 35.28 - min: 31.75)
#
# Episode  47 - 08:03 - Score: 34.81 (max: 39.36 - min: 25.55)
# Moving average: 34.13 (max: 35.54 - min: 31.86)
#
# Episode  48 - 08:09 - Score: 34.41 (max: 38.55 - min: 26.23)
# Moving average: 34.14 (max: 35.44 - min: 31.87)
#
# Episode  49 - 08:07 - Score: 35.23 (max: 39.41 - min: 27.82)
# Moving average: 34.24 (max: 35.30 - min: 32.15)
#
# Episode  50 - 08:16 - Score: 35.65 (max: 38.68 - min: 29.26)
# Moving average: 34.32 (max: 35.59 - min: 32.40)
#
# Saving model ...
#
# Episode  51 - 08:15 - Score: 36.00 (max: 39.58 - min: 32.73)
# Moving average: 34.50 (max: 35.61 - min: 32.69)
#
# Episode  52 - 08:06 - Score: 31.93 (max: 37.54 - min: 19.16)
# Moving average: 34.22 (max: 35.52 - min: 32.57)
#
# Episode  53 - 08:11 - Score: 32.21 (max: 39.30 - min: 18.79)
# Moving average: 34.06 (max: 35.62 - min: 31.92)
#
# Episode  54 - 07:55 - Score: 33.51 (max: 38.77 - min: 19.23)
# Moving average: 33.95 (max: 35.53 - min: 32.25)
#
# Episode  55 - 07:56 - Score: 35.02 (max: 39.59 - min: 20.37)
# Moving average: 33.93 (max: 35.45 - min: 31.82)
#
# Episode  56 - 08:04 - Score: 33.35 (max: 39.45 - min: 23.90)
# Moving average: 33.92 (max: 35.16 - min: 31.99)
#
# Episode  57 - 08:11 - Score: 32.51 (max: 39.19 - min: 27.93)
# Moving average: 33.76 (max: 35.32 - min: 31.82)
#
# Episode  58 - 08:04 - Score: 36.65 (max: 39.20 - min: 33.42)
# Moving average: 33.80 (max: 35.41 - min: 31.76)
#
# Episode  59 - 08:05 - Score: 29.90 (max: 38.08 - min: 14.67)
# Moving average: 33.67 (max: 34.93 - min: 32.15)
#
# Episode  60 - 08:08 - Score: 33.39 (max: 38.82 - min: 28.38)
# Moving average: 33.66 (max: 34.99 - min: 32.37)
#
# Saving model ...
#
# Episode  61 - 08:09 - Score: 33.03 (max: 38.79 - min: 23.62)
# Moving average: 33.62 (max: 34.76 - min: 32.41)
#
# Episode  62 - 08:11 - Score: 36.92 (max: 39.60 - min: 30.78)
# Moving average: 34.02 (max: 35.13 - min: 32.69)
#
# Episode  63 - 08:14 - Score: 34.30 (max: 39.44 - min: 24.67)
# Moving average: 34.13 (max: 35.10 - min: 32.44)
#
# Episode  64 - 08:11 - Score: 35.13 (max: 39.65 - min: 23.00)
# Moving average: 34.29 (max: 35.56 - min: 33.04)
# Episode  65 - 08:09 - Score: 32.66 (max: 38.12 - min: 18.64)
# Moving average: 34.07 (max: 35.38 - min: 32.74)
#
# Episode  66 - 08:22 - Score: 38.44 (max: 39.64 - min: 30.99)
# Moving average: 34.25 (max: 35.54 - min: 33.03)
#
# Episode  67 - 08:36 - Score: 34.09 (max: 39.61 - min: 20.17)
# Moving average: 34.22 (max: 35.32 - min: 33.08)
#
# Episode  68 - 08:23 - Score: 34.45 (max: 39.42 - min: 26.58)
# Moving average: 34.22 (max: 35.65 - min: 33.18)
#
# Episode  69 - 08:36 - Score: 30.57 (max: 36.07 - min: 27.24)
# Moving average: 33.99 (max: 35.52 - min: 32.96)
#
# Episode  70 - 08:22 - Score: 35.63 (max: 39.63 - min: 30.59)
# Moving average: 33.98 (max: 35.49 - min: 32.55)
#
# Saving model ...
#
# Episode  71 - 09:05 - Score: 37.03 (max: 39.48 - min: 32.05)
# Moving average: 34.04 (max: 35.56 - min: 32.79)
#
# Episode  72 - 08:56 - Score: 33.40 (max: 39.49 - min: 15.15)
# Moving average: 34.11 (max: 35.72 - min: 32.63)
#
# Episode  73 - 08:54 - Score: 33.77 (max: 38.65 - min: 26.42)
# Moving average: 34.19 (max: 35.58 - min: 32.20)
#
# Episode  74 - 08:41 - Score: 31.55 (max: 36.29 - min: 24.03)
# Moving average: 34.09 (max: 35.47 - min: 32.11)
#
# Episode  75 - 08:41 - Score: 29.84 (max: 35.51 - min: 20.01)
# Moving average: 33.83 (max: 34.73 - min: 31.67)
#
# Episode  76 - 08:21 - Score: 30.86 (max: 39.46 - min: 22.29)
# Moving average: 33.71 (max: 34.70 - min: 31.83)
#
# Episode  77 - 08:24 - Score: 36.19 (max: 38.96 - min: 30.12)
# Moving average: 33.89 (max: 34.73 - min: 31.98)
#
# Episode  78 - 08:16 - Score: 35.97 (max: 38.78 - min: 31.39)
# Moving average: 33.86 (max: 34.97 - min: 31.59)
#
# Episode  79 - 08:43 - Score: 34.05 (max: 37.64 - min: 30.27)
# Moving average: 34.06 (max: 35.34 - min: 32.44)
#
# Episode  80 - 08:46 - Score: 37.30 (max: 39.19 - min: 29.89)
# Moving average: 34.26 (max: 35.33 - min: 32.61)
#
# Saving model ...
#
# Episode  81 - 08:56 - Score: 35.45 (max: 38.33 - min: 30.16)
# Moving average: 34.38 (max: 35.47 - min: 32.87)
#
# Episode  82 - 08:52 - Score: 34.03 (max: 38.44 - min: 20.25)
# Moving average: 34.24 (max: 35.35 - min: 32.64)
#
# Episode  83 - 08:33 - Score: 32.58 (max: 37.67 - min: 18.83)
# Moving average: 34.15 (max: 35.34 - min: 32.27)
#
# Episode  84 - 08:32 - Score: 35.05 (max: 39.37 - min: 16.51)
# Moving average: 34.15 (max: 35.20 - min: 32.19)
#
# Episode  85 - 08:28 - Score: 36.09 (max: 39.59 - min: 29.12)
# Moving average: 34.32 (max: 35.56 - min: 32.33)
#
# Episode  86 - 08:40 - Score: 34.45 (max: 38.49 - min: 25.52)
# Moving average: 34.12 (max: 35.54 - min: 32.24)
#
# Episode  87 - 08:56 - Score: 31.88 (max: 37.52 - min: 22.61)
# Moving average: 34.01 (max: 35.19 - min: 32.03)
#
# Episode  88 - 08:43 - Score: 32.72 (max: 37.05 - min: 27.54)
# Moving average: 33.92 (max: 35.31 - min: 31.73)
#
# Episode  89 - 08:26 - Score: 31.03 (max: 37.05 - min: 24.78)
# Moving average: 33.94 (max: 35.08 - min: 31.81)
#
# Episode  90 - 08:25 - Score: 33.84 (max: 39.08 - min: 23.23)
# Moving average: 33.85 (max: 35.28 - min: 31.39)
#
# Saving model ...
#
# Episode  91 - 08:32 - Score: 38.11 (max: 39.42 - min: 35.25)
# Moving average: 33.91 (max: 35.32 - min: 31.39)
#
# Episode  92 - 08:37 - Score: 36.43 (max: 39.56 - min: 20.00)
# Moving average: 34.06 (max: 35.23 - min: 31.44)
#
# Episode  93 - 08:31 - Score: 33.44 (max: 37.90 - min: 28.52)
# Moving average: 34.04 (max: 35.18 - min: 31.54)
#
# Episode  94 - 08:35 - Score: 34.63 (max: 39.58 - min: 20.99)
# Moving average: 34.20 (max: 35.35 - min: 32.23)
#
# Episode  95 - 08:37 - Score: 33.99 (max: 39.53 - min: 23.70)
# Moving average: 34.40 (max: 35.90 - min: 32.46)
#
# Episode  96 - 08:38 - Score: 32.53 (max: 38.96 - min: 22.43)
# Moving average: 34.49 (max: 35.91 - min: 32.35)
#
# Episode  97 - 08:38 - Score: 33.83 (max: 39.47 - min: 29.70)
# Moving average: 34.37 (max: 35.55 - min: 32.49)
#
# Episode  98 - 08:36 - Score: 34.57 (max: 39.24 - min: 29.80)
# Moving average: 34.30 (max: 35.37 - min: 32.37)
#
# Episode  99 - 08:37 - Score: 28.40 (max: 35.79 - min: 19.64)
# Moving average: 34.02 (max: 34.98 - min: 31.92)
#
# Episode 100 - 08:37 - Score: 34.17 (max: 38.75 - min: 26.92)
# Moving average: 33.86 (max: 34.94 - min: 31.64)
#
# Saving model ...
#
#
# Environment solved in 100 episodes!	Average Score: 33.86	Elapsed time: 13h36m03s
# Saving model ...

# %%
from agent import HParameters
p = Plotter(scores, HParameters.target_score, moving_avg, num_agents)
p.plot_agent()
# Out:
# (array([ 1.04499998,  1.92574996,  2.60816661,  3.18249993,  3.81509991,
#          4.80874989,  5.73392844,  6.51443735,  7.21405539,  7.61739983,
#          8.3719089 ,  9.05083313,  9.63334594, 10.06149978, 10.4800331 ,
#         10.91481226, 11.47155857, 12.35924972, 13.22421023, 14.17767468,
#         15.31312466, 16.70587463, 18.12817459, 19.49727456, 20.67124954,
#         21.89577451, 22.93774949, 24.04709946, 25.06757444, 26.21469941,
#         27.0370494 , 28.08352437, 29.02527435, 30.03284933, 30.98159931,
#         31.79272429, 32.55404927, 32.97244926, 33.15772426, 33.22949926,
#         33.72407425, 33.64609925, 33.62392425, 33.61024925, 33.96547424,
#         33.99599924, 34.13014924, 34.14234924, 34.24259923, 34.31554923,
#         34.49742423, 34.22129924, 34.05882424, 33.94517424, 33.93052424,
#         33.91522424, 33.76057425, 33.80209924, 33.67227425, 33.65529925,
#         33.62449925, 34.01542424, 34.13164924, 34.28737423, 34.07414924,
#         34.25234923, 34.21657424, 34.21879924, 33.98584924, 33.98497424,
#         34.03652424, 34.11029924, 34.18842424, 34.09044924, 33.83142424,
#         33.70669925, 33.89047424, 33.85667424, 34.06392424, 34.25959923,
#         34.38052423, 34.23612423, 34.15004924, 34.14624924, 34.31729923,
#         34.11777424, 34.00719924, 33.92052424, 33.94362424, 33.85429924,
#         33.90809924, 34.05932424, 34.04274924, 34.19714924, 34.40447423,
#         34.48814923, 34.37047423, 34.30024923, 34.01797424, 33.86144924]),
#  [30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30])

# %%
env.close()
